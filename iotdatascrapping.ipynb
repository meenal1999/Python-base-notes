# %%
import urllib.request, urllib.parse,urllib.error

fhandle=urllib.request.urlopen('https://www.shiksha.com/university/jiit-jaypee-institute-of-information-technology-noida-20383')
for var in fhandle:
    var=var.strip()
    if var.find('<div class= tabv_1 >'):
        print(var)
print("dfzvdf")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-88a0b492e701> in <module>
#       1 import urllib.request, urllib.parse,urllib.error
#       2
# ----> 3 fhandle=urllib.request.urlopen('https://www.shiksha.com/university/jiit-jaypee-institute-of-information-technology-noida-20383')
#       4 for var in fhandle:
#       5     var=var.strip()
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\users\meenal\appdata\local\programs\python\python37-32\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
# ...

# %%
fhandle=open('iot', encoding="utf8")
count=0
for var in fhandle:
    var=var.strip()
    count=count+1
    if count%6==0:
        print(var[var.find("href= # ")+9:var.find("</a>")])
    elif count%11==0:
        count=0
# Out:
# allusion
# coherence
# conciseness
# parallelism
# tragedy
# soliloquy
# comedy
# foil
# monologue
# denotation
# euphemism
# subjective
# dynamic
# antecedent
# archetype
# coherence
# digital media
# allegory
# parable
# consensus
# synthesize
# abstract
# counterclaim
# validity
# plagiarism
# syntax
# subtle
# annotate
# diction
# rhetoric
# implicit
# nuance
# paradox
# ballad
# circumlocution
# consonance
# couplet
# dictation
# censorship
# norm
# memorandum
# inflection
# negotiate
# cognate
# ode
# poise
# satire
# memorandum
# ethics
# modulation
# pastoral
# microfiche
# red herring
# parable
# incongruity
# criteria
# dash
# resume
# marketing
# persona

# %%
fhandle=open('iot', encoding="utf8")
for var in fhandle:
    var=var.strip()
    if var.startswith("d."):
        print(var[3:])

# %%
fhandle=open('iot', encoding="utf8")
for var in fhandle:
    var=var.rstrip()
    if var.startswith("c)"):
        print(var[3:])

# %%
fhandle=open('iot', encoding="utf8")
for var in fhandle:
    var=var.rstrip()
    if var.startswith("d."):
        print(var[3:])
# Out:
# Resource pooling
# Intellectual property protection
# Encryption for data in transit has a speed/strength tradeoff.
# Cloud-based management platforms can support change management methodologies.
#      Administrative access control
#      By restricting access to information
#      An operating system for private network systems
#      Both a and b
#      Both a and b
#      Both a and B
#      D. Storage in the Cloud is easier to protect against intrusion
#      To have time to accommodate the local network to use of the new services
#      All of the above
#      Red Hat
#      GAE
#      Zombies
#      Backdoor channel attack
#      Media Distribution
#      Both a and b
#      Common platform as a Service
#      Salesforce.com
#      Storage in the Cloud is easier to protect against intrusion
#      Hybrid cloud
#      To have time to accommodate the local network to use of the new services
#      There is no difference between the service models.
# ...

# %%
fhandle=open('iot','r')
count=0
for var in fhandle:
    var=var.strip()
    if count==1:
        print(var)
        count=0
    elif var.startswith("<div class= question >"):
        count=1
# Out:
# What is the benefit of SDN for IoT devices
# ITS stands for _________
# Services in a microservice architecture are â€¦â€¦â€¦. that communicates with each other over the network.
# Which change occur when cloud computing for IoT devices, is utilized?
# <p>Compute the value of 'x'  from following Python expression</p><p>x = 17 / 2 * 3 + 2</p>
# Presence of a single key in the Python dictionary, is done by
# Which amongst the following best describe IoT architecture?
# ________ is an application layer protocol for resource constrained devices.
# Which protocol is used by SNMP for IoT devices
# How many bit address is provided for network address, in IPv4, for IoT devices
# With the help of IPv6 addressing protocol, _________________ can be connected directly to the internet.
#
# Web is a mesh of computers, so too is _________
# ...

# %%
import os
import sys
import fileinput
'''
print ("Text to search for:")
textToSearch = input( "> " )

print ("Text to replace it with:")
textToReplace = input( "> " )

print ("File to perform Search-Replace on:")
fileToSearch  = input( "> " )
#fileToSearch = 'D:\dummy1.txt'
'''

tempFile = open( "iot.txt", 'r+' )

for line in fileinput.input( fileToSearch ):
    if '''"''' in line :
        print('Match Found')
    else:
        print('Match Not Found!!')
    tempFile.write( line.replace( textToSearch, " `" ) )
tempFile.close()


input( '\n\n Press Enter to exit...' )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-186c7fc67a01> in <module>
#      14 '''
#      15
# ---> 16 tempFile = open( "iot.txt", 'r+' )
#      17
#      18 for line in fileinput.input( fileToSearch ):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'iot.txt'

# %%
#replace " " with spaces
with open('iot', 'r') as file :
  filedata = open("iot").read()

# Replace the target string
filedata = filedata.replace('"', ' ')

# Write the file out again
with open('iot', 'w') as file:
  file.write(filedata)

# %%
fhandle=open('iot','r')

count=0
for var in fhandle:
    var=var.strip()
    if count<=0 and var.startswith("<div class= tabv_1 >"):
        print(var)
        count=count+1
    elif count==1:
        count=count+1
    elif count==2 and var.startswith("<strong>"):
        print(var[var.find("<strong>")+8:var.find("</strong>")-2])
        count=0
# Out:
# <div class= tabv_1 >
# >Placements
# <div class= tabv_1 >
# >Placements
# <div class= tabv_1 >
# >Placements
# <div class= tabv_1 >
# >Placements

# %%
#find subtopics
fhandle=open('iot','r')
count=0
for var in fhandle:
    var=var.strip()
    if var.startswith("<div class= tabv_1 >"):
        count=1
    elif var.startswith("</div>"):
        count=0
    if count==1 and var.startswith("<strong>"):
        print(var[var.find("<strong>")+8:var.find("</strong>")-2])
# Out:
# Placements
# Infrastructure
# Faculty
# Placements
# Infrastructure
# Placements
# Infrastructure
# Placements
# Infrastructure

# %%
#open url
from requests import get
fhandle=open('iot','r')
count=0
for var in fhandle:
    var=var.strip()
    if var.startswith("<div class= tabv_1 >"):
        count=1
    elif var.startswith("</div>"):
        count=0
    if count==1 and var.startswith("<a href="):
        #open url
        print(var[var.find("<a href=")+8:var.find("class=")-2]) 
        str=var[var.find("<a href=")+8:var.find("class=")-2]

#r = requests.post(str, data=dict(email="meenal1999@gmail.com",password="Complicated1"))
#response=get(str)
#print(r.text)
# Out:
#  https://www.shiksha.com/university/jiit-jaypee-institute-of-information-technology-noida-20383/reviews#394785
#  https://www.shiksha.com/university/jiit-jaypee-institute-of-information-technology-noida-20383/reviews#391183
#  https://www.shiksha.com/university/jiit-jaypee-institute-of-information-technology-noida-20383/reviews#379559
#  https://www.shiksha.com/university/jiit-jaypee-institute-of-information-technology-noida-20383/reviews#374467
# <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;www&#46;shiksha&#46;com&#47;university&#47;jiit&#45;jaypee&#45;institute&#45;of&#45;information&#45;technology&#45;noida&#45;20383&#47;reviews" on this server.<P>
# Reference&#32;&#35;18&#46;24210f17&#46;1566579054&#46;4acb7793
# </BODY>
# </HTML>

# %%
#find subtopics
fhandle=open('iot','r')
count=0
vari=0
for var in fhandle:
    var=var.strip()
    if vari==1:
        print(var)
        vari=0
        #emit <br> and <p> here 
    if var.startswith("<div class= tabv_1 >"):
        count=1
    elif var.startswith("</div>"):
        count=0
    if count==1 and var.startswith("<strong>"):
        vari=1
    
        #print(var[var.find("<strong>")+8:var.find("</strong>")-2])
# Out:
# Placements are avg. Mostly major recruiters are mass recruiters. Avg salary varies around 3 lacs to 4 lacs. Mainly CS placements good compared to other branches. Mainly IT jobs were offered by the major companies. Yes, there is a placement cell in college but it's not that active but they try their best.                               <p>
# Labs are well equipped. Quality of labs are pretty average. Mostly equipments are not working or damaged. Infact many a times 4-5 students have only one set of equipments. Other than that campus is pretty big with a really big auditorium infact is at the major location surrounded by the offices of most to the top companies.
# Some teachers ar...                              <br>
# ...

# %%
#access html data as list where no problem of access

import requests 
from bs4 import BeautifulSoup 
  
URL = "https://collegedunia.com/university/25953-jaypee-institute-of-information-technology-university-jiit-noida/reviews"
r = requests.get(URL) 
  
soup = BeautifulSoup(r.content, 'html5lib') 
soup=soup.prettify()
print(soup)

# %%
#access html data as list where there is problem of access

import requests
from bs4 import BeautifulSoup as BS

url = 'https://www.shiksha.com/university/jiit-jaypee-institute-of-information-technology-noida-20383/reviews'
agent ={"User-Agent":"Mozilla/5.0"}
page = requests.get(url, headers=agent).text
print (page)
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="https://www.facebook.com/2008/fbml">
# <head>
# <title>JIIT - Jaypee Institute of Information Technology Noida Reviews on Placements, Faculty and Facilities</title>
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1" />
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <link rel="dns-prefetch" href="//js.shiksha.ws">
# <link rel="dns-prefetch" href="//css.shiksha.ws">
# <link rel="dns-prefetch" href="//images.shiksha.ws">
# <link rel="dns-prefetch" href="https://images.shiksha.com">
# <link rel="preconnect" href="//js.shiksha.ws" crossorigin>
# <link rel="preconnect" href="//css.shiksha.ws" crossorigin>
# <link rel="preconnect" href="https://images.shiksha.com" crossorigin>
# <meta name="verify-v1" content="4ijm0YHCDh8EJGQiN9HxXsBccQg1cbkBQi6bCRo/xcQ="/>
# ...
